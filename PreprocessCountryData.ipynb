# %% [markdown]
# <a href="https://colab.research.google.com/github/tuananh1006/Web-Scraping-Book/blob/main/PreprocessCountryData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://en.wikipedia.org/wiki/List_of_countries_with_McDonald%27s_restaurants')
bs = BeautifulSoup(html, 'html.parser')
# The main comparison table is currently the first table on the page
table = bs.find_all('table',{'class':'wikitable'})[0]
rows = table.findAll('tr')
csvFile = open('countries.csv', 'wt+')
writer = csv.writer(csvFile)
try:
    for row in rows:
        csvRow = []
        for cell in row.findAll(['td', 'th']):
          a=cell.find('a',{'rel':'nofollow'})
          if a:
            csvRow.append(a['href'])
          else:
            csvRow.append(cell.get_text().strip())
        writer.writerow(csvRow)
finally:
    csvFile.close()

# %%
import pandas as pd
df=pd.read_csv('countries.csv')

# %%
df.rename(columns={
    '#': 'Order',
    'Country/territory': 'Country',
    'Date of first store': 'Date',
    'First outlet location': 'Location',
    'Max. no. ofoperatingoutlets': 'Outlets'
}, inplace=True)

# %%
df.head(10)
# Out:
#    Order                                            Country  \
# 0      1                                      United States
# 1      2                                   Canada (details)
# 2      3            Puerto Rico(territory of United States)
# 3      4  United States Virgin Islands(territory of Unit...
# 4      5                                         Costa Rica
# 5      6                                          Australia
# 6      7                   Guam(territory of United States)
# 7      8                                              Japan
# 8      9                                        Netherlands
# 9     10                                             Panama
#
#                                     Date  \
# 0  May 15, 1940Franchise: April 15, 1955
# 1                           June 3, 1967
# 2                      November 10, 1967
# 3                      September 5, 1970
# 4                       December 8, 1970
# 5                           May 30, 1971
# 6                          June 10, 1971
# 7                          July 21, 1971
# 8                        August 21, 1971
# 9                      September 1, 1971
#
#                                             Location  Outlets  \
# 0  San Bernardino, CaliforniaDes Plaines, Illinoi...   13,449
# 1  Richmond, British Columbia(Reopened June 23, 2...    1,466
# 2                                           San Juan       95
# 3                                          St. Croix        5
# 4  San José, 4th street, between 1st and Central ...       73
# 5                       Yagoona, New South Wales[13]    1,032
# 6                                             Dededo        5
# 7          Ginza Mitsukoshi, Ginza, Chuo City, Tokyo    2,982
# 8                                            Zaandam  263[16]
# 9                                        Panama City       81
#
#                            Source and date of source People per outlet  \
# 0  (source: Corporate McDonald's December 31, 202...            25,539
# 1  (source: Corporate McDonald's December 31, 202...            28,807
# 2  (source: Corporate McDonald's December 31, 202...            34,127
# 3  (source: Corporate McDonald's December 31, 202...            17,140
# 4  (source: Corporate McDonald's December 31, 202...            69,939
# 5  (source: Corporate McDonald's December 31, 202...            25,631
# 6  (source: Corporate McDonald's December 31, 202...            33,301
# 7  (source: Corporate McDonald's December 31, 202...            41,707
# 8  (source: Corporate McDonald's December 31, 202...            68,793
# 9  (source: Corporate McDonald's December 31, 202...            55,046
#
#                                      Notes
# 0  https://www.mcdonalds.com/us/en-us.html
# 1  https://www.mcdonalds.com/ca/en-ca.html
# 2             http://www.mcdonalds.com.pr/
# 3                                      NaN
# 4              http://www.mcdonalds.co.cr/
# 5                https://mcdonalds.com.au/
# 6  https://www.mcdonaldsguamandsaipan.com/
# 7             https://www.mcdonalds.co.jp/
# 8  https://www.mcdonalds.com/nl/nl-nl.html
# 9             http://www.mcdonalds.com.pa/

# %%
df= df[['Order', 'Country', 'Date', 'Location', 'Outlets']]

# %%
df.head(5)
# Out:
#    Order                                            Country  \
# 0      1                                      United States
# 1      2                                   Canada (details)
# 2      3            Puerto Rico(territory of United States)
# 3      4  United States Virgin Islands(territory of Unit...
# 4      5                                         Costa Rica
#
#                                     Date  \
# 0  May 15, 1940Franchise: April 15, 1955
# 1                           June 3, 1967
# 2                      November 10, 1967
# 3                      September 5, 1970
# 4                       December 8, 1970
#
#                                             Location Outlets
# 0  San Bernardino, CaliforniaDes Plaines, Illinoi...  13,449
# 1  Richmond, British Columbia(Reopened June 23, 2...   1,466
# 2                                           San Juan      95
# 3                                          St. Croix       5
# 4  San José, 4th street, between 1st and Central ...      73

# %%
date_regex = re.compile('[A-Z][a-z]+ [0-9]{1,2}, +[0-9]{4}')
CITATION_REGEX = re.compile('\[[0-9]*\]')
def strip_citations(text):
    return re.sub(CITATION_REGEX, '', text)
date_regex.findall(strip_citations(df['Date'][113]))
# Out:
# ['December 29,  2014']

# %%
import re

date_regex = re.compile('[A-Z][a-z]+ [0-9]{1,2}, +[0-9]{4}')

# %%
try:
  df['Date'] = df['Date'].apply(lambda d: date_regex.findall(d)[0])
except IndexError as e:
  print(e)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head(10)
# Out:
#    Order                                            Country       Date  \
# 0      1                                      United States 1940-05-15
# 1      2                                   Canada (details) 1967-06-03
# 2      3            Puerto Rico(territory of United States) 1967-11-10
# 3      4  United States Virgin Islands(territory of Unit... 1970-09-05
# 4      5                                         Costa Rica 1970-12-08
# 5      6                                          Australia 1971-05-30
# 6      7                   Guam(territory of United States) 1971-06-10
# 7      8                                              Japan 1971-07-21
# 8      9                                        Netherlands 1971-08-21
# 9     10                                             Panama 1971-09-01
#
#                                             Location  Outlets  DateNew
# 0  San Bernardino, CaliforniaDes Plaines, Illinoi...   13,449        2
# 1  Richmond, British Columbia(Reopened June 23, 2...    1,466        1
# 2                                           San Juan       95        1
# 3                                          St. Croix        5        1
# 4  San José, 4th street, between 1st and Central ...       73        1
# 5                       Yagoona, New South Wales[13]    1,032        1
# 6                                             Dededo        5        1
# 7          Ginza Mitsukoshi, Ginza, Chuo City, Tokyo    2,982        1
# 8                                            Zaandam  263[16]        1
# 9                                        Panama City       81        1

# %%
int_regex = re.compile('[0-9,]+')

def str_to_int(s):
    s = int_regex.findall(s)[0]
    s = s.replace(',','')
    return int(s)

df['Outlets'] = df['Outlets'].apply(str_to_int)

# %%
df.head(5)
# Out:
#    Order                                            Country       Date  \
# 0      1                                      United States 1940-05-15
# 1      2                                   Canada (details) 1967-06-03
# 2      3            Puerto Rico(territory of United States) 1967-11-10
# 3      4  United States Virgin Islands(territory of Unit... 1970-09-05
# 4      5                                         Costa Rica 1970-12-08
#
#                                             Location  Outlets  DateNew
# 0  San Bernardino, CaliforniaDes Plaines, Illinoi...    13449        2
# 1  Richmond, British Columbia(Reopened June 23, 2...     1466        1
# 2                                           San Juan       95        1
# 3                                          St. Croix        5        1
# 4  San José, 4th street, between 1st and Central ...       73        1

# %%
def str_to_int(s):
    try:
        s = int_regex.findall(s)[0]
        s = s.replace(',','')
    except:
        print(f'Whoops: {s}')
    return int(s)

# %%
df.set_index(['Order'], inplace=True)
df.head()
# Out:
#                                                  Country       Date  \
# Order
# 1                                          United States 1940-05-15
# 2                                       Canada (details) 1967-06-03
# 3                Puerto Rico(territory of United States) 1967-11-10
# 4      United States Virgin Islands(territory of Unit... 1970-09-05
# 5                                             Costa Rica 1970-12-08
#
#                                                 Location  Outlets  DateNew
# Order
# 1      San Bernardino, CaliforniaDes Plaines, Illinoi...    13449        2
# 2      Richmond, British Columbia(Reopened June 23, 2...     1466        1
# 3                                               San Juan       95        1
# 4                                              St. Croix        5        1
# 5      San José, 4th street, between 1st and Central ...       73        1

# %%
df.sort_values(by=['Outlets', 'Date'], ascending=False)
# Out:
#                                       Country       Date  \
# Order
# 1                               United States 1940-05-15
# 48                                      China 1990-10-08
# 8                                       Japan 1971-07-21
# 12                           France (details) 1972-06-30
# 2                            Canada (details) 1967-06-03
# ...                                       ...        ...
# 96           Jersey(British Crown dependency) 1997-08-01
# 85                              Liechtenstein 1996-05-03
# 83     Samoa(named Western Samoa at the time) 1996-03-02
# 58                                     Monaco 1992-11-20
# 41                                       Cuba 1986-04-24
#
#                                                 Location  Outlets  DateNew
# Order
# 1      San Bernardino, CaliforniaDes Plaines, Illinoi...    13449        2
# 48                     Dongmen, Luohu District, Shenzhen     5903        1
# 8              Ginza Mitsukoshi, Ginza, Chuo City, Tokyo     2982        1
# 12                                               Créteil     1559        1
# 2      Richmond, British Columbia(Reopened June 23, 2...     1466        1
# ...                                                  ...      ...      ...
# 96                                          Saint Helier        1        1
# 85                                               Triesen        1        1
# 83                                                  Apia        1        1
# 58                                           Monte Carlo        1        1
# 41                                        Guantanamo Bay        1        1
#
# [115 rows x 5 columns]

# %%
df.query('Outlets < 100')
# Out:
#                                                  Country       Date  \
# Order
# 3                Puerto Rico(territory of United States) 1967-11-10
# 4      United States Virgin Islands(territory of Unit... 1970-09-05
# 5                                             Costa Rica 1970-12-08
# 7                       Guam(territory of United States) 1971-06-10
# 10                                                Panama 1971-09-01
# ...                                                  ...        ...
# 111                                            Mauritius 2001-07-04
# 112                                                 Iraq 2006-08-10
# 113                                              Vietnam 2014-02-08
# 114                   Saint Martin (territory of France) 2014-12-29
# 115            Western Sahara (Area occupied by Morocco) 2017-08-10
#
#                                                 Location  Outlets  DateNew
# Order
# 3                                               San Juan       95        1
# 4                                              St. Croix        5        1
# 5      San José, 4th street, between 1st and Central ...       73        1
# 7                                                 Dededo        5        1
# 10                                           Panama City       81        1
# ...                                                  ...      ...      ...
# 111                                           Port Louis       16        1
# 112                                              Baghdad        1        1
# 113                                     Ho Chi Minh City       33        1
# 114                                              Marigot        1        1
# 115                                             Laayoune        1        1
#
# [73 rows x 5 columns]

# %%
df.query('Date != None')
# Out:
#                                                  Country       Date  \
# Order
# 1                                          United States 1940-05-15
# 2                                       Canada (details) 1967-06-03
# 3                Puerto Rico(territory of United States) 1967-11-10
# 4      United States Virgin Islands(territory of Unit... 1970-09-05
# 5                                             Costa Rica 1970-12-08
# ...                                                  ...        ...
# 111                                            Mauritius 2001-07-04
# 112                                                 Iraq 2006-08-10
# 113                                              Vietnam 2014-02-08
# 114                   Saint Martin (territory of France) 2014-12-29
# 115            Western Sahara (Area occupied by Morocco) 2017-08-10
#
#                                                 Location  Outlets  DateNew
# Order
# 1      San Bernardino, CaliforniaDes Plaines, Illinoi...    13449        2
# 2      Richmond, British Columbia(Reopened June 23, 2...     1466        1
# 3                                               San Juan       95        1
# 4                                              St. Croix        5        1
# 5      San José, 4th street, between 1st and Central ...       73        1
# ...                                                  ...      ...      ...
# 111                                           Port Louis       16        1
# 112                                              Baghdad        1        1
# 113                                     Ho Chi Minh City       33        1
# 114                                              Marigot        1        1
# 115                                             Laayoune        1        1
#
# [115 rows x 5 columns]

# %%
df.query('Date.isnull()')
df.query('Date.notnull()')
# Out:
#                                                  Country       Date  \
# Order
# 1                                          United States 1940-05-15
# 2                                       Canada (details) 1967-06-03
# 3                Puerto Rico(territory of United States) 1967-11-10
# 4      United States Virgin Islands(territory of Unit... 1970-09-05
# 5                                             Costa Rica 1970-12-08
# ...                                                  ...        ...
# 111                                            Mauritius 2001-07-04
# 112                                                 Iraq 2006-08-10
# 113                                              Vietnam 2014-02-08
# 114                   Saint Martin (territory of France) 2014-12-29
# 115            Western Sahara (Area occupied by Morocco) 2017-08-10
#
#                                                 Location  Outlets  DateNew
# Order
# 1      San Bernardino, CaliforniaDes Plaines, Illinoi...    13449        2
# 2      Richmond, British Columbia(Reopened June 23, 2...     1466        1
# 3                                               San Juan       95        1
# 4                                              St. Croix        5        1
# 5      San José, 4th street, between 1st and Central ...       73        1
# ...                                                  ...      ...      ...
# 111                                           Port Louis       16        1
# 112                                              Baghdad        1        1
# 113                                     Ho Chi Minh City       33        1
# 114                                              Marigot        1        1
# 115                                             Laayoune        1        1
#
# [115 rows x 5 columns]

# %%
df.query('Outlets < 100 & Date < "01-06-1990"')
# Out:
#                                                  Country       Date  \
# Order
# 3                Puerto Rico(territory of United States) 1967-11-10
# 4      United States Virgin Islands(territory of Unit... 1970-09-05
# 5                                             Costa Rica 1970-12-08
# 7                       Guam(territory of United States) 1971-06-10
# 10                                                Panama 1971-09-01
# 13                                           El Salvador 1972-07-20
# 16     Curaçao(part of Netherlands Antilles at the time) 1974-08-16
# 19                                               Bahamas 1975-08-04
# 22                                               Ireland 1977-05-09
# 31                                                Norway 1983-11-18
# 33                                               Andorra 1984-06-29
# 34                                               Finland 1984-12-14
# 37       Aruba(part of Netherlands Antilles at the time) 1985-04-04
# 38                                            Luxembourg 1985-07-17
# 39                                             Venezuela 1985-08-31
# 41                                                  Cuba 1986-04-24
# 44                   Macau(Portuguese Macau at the time) 1987-04-11
# 45                Serbia(part of Yugoslavia at the time) 1988-03-24
#
#                                                 Location  Outlets  DateNew
# Order
# 3                                               San Juan       95        1
# 4                                              St. Croix        5        1
# 5      San José, 4th street, between 1st and Central ...       73        1
# 7                                                 Dededo        5        1
# 10                                           Panama City       81        1
# 13                                          San Salvador       22        1
# 16                                            Willemstad        5        1
# 19                                                Nassau        3        1
# 22                                Grafton Street, Dublin       95        1
# 31                                Nedre Slottsgate, Oslo       79        1
# 33                                      Andorra la Vella        5        1
# 34                                Hämeenkatu 17, Tampere       75        1
# 37                                            Oranjestad        3        1
# 38                                       Luxembourg City       12        1
# 39                        El Rosal, Caracas (now closed)       83        1
# 41                                        Guantanamo Bay        1        1
# 44       Rua do Campo, Cathedral Parish, Macau Peninsula       39        1
# 45                              Slavija Square, Belgrade       33        1

# %%
df.query('Outlets < 100 | Date < "01-06-1990"')
# Out:
#                                                  Country       Date  \
# Order
# 1                                          United States 1940-05-15
# 2                                       Canada (details) 1967-06-03
# 3                Puerto Rico(territory of United States) 1967-11-10
# 4      United States Virgin Islands(territory of Unit... 1970-09-05
# 5                                             Costa Rica 1970-12-08
# ...                                                  ...        ...
# 111                                            Mauritius 2001-07-04
# 112                                                 Iraq 2006-08-10
# 113                                              Vietnam 2014-02-08
# 114                   Saint Martin (territory of France) 2014-12-29
# 115            Western Sahara (Area occupied by Morocco) 2017-08-10
#
#                                                 Location  Outlets  DateNew
# Order
# 1      San Bernardino, CaliforniaDes Plaines, Illinoi...    13449        2
# 2      Richmond, British Columbia(Reopened June 23, 2...     1466        1
# 3                                               San Juan       95        1
# 4                                              St. Croix        5        1
# 5      San José, 4th street, between 1st and Central ...       73        1
# ...                                                  ...      ...      ...
# 111                                           Port Louis       16        1
# 112                                              Baghdad        1        1
# 113                                     Ho Chi Minh City       33        1
# 114                                              Marigot        1        1
# 115                                             Laayoune        1        1
#
# [102 rows x 5 columns]
